# %%
import pandas as pd
df_confirmed = pd.read_csv('time_series_covid_19_confirmed.csv') # 확진자 데이터프레임
df_deaths = pd.read_csv('time_series_covid_19_deaths.csv') # 사망자 데이터프레임
df_recovered = pd.read_csv('time_series_covid_19_recovered.csv') # 회복자 데이터프레임

# %%
df_confirmed.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  \
# 0        0        0        0        0        0        0  ...    64575
# ...

# %%
df_deaths.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  \
# 0        0        0        0        0        0        0  ...     2772
# ...

# %%
df_recovered.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...    55687    55790    55889
# 1        0        0        0        0  ...   127869   128425   128601
# 2        0        0        0        0  ...    87902    88066    88208
# 3        0        0        0        0  ...    13234    13234    13234
# 4        0        0        0        0  ...    26483    26513    26775
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
df_confirmed['Country/Region'].value_counts()
# Out:
# Country/Region
# China                 34
# Canada                16
# France                12
# United Kingdom        12
# Australia              8
#                       ..
# Vietnam                1
# West Bank and Gaza     1
# Yemen                  1
# Zambia                 1
# Zimbabwe               1
# Name: count, Length: 193, dtype: int64

# %%
df_confirmed['Country/Region'] == 'Korea, South'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 271    False
# 272    False
# 273    False
# 274    False
# 275    False
# Name: Country/Region, Length: 276, dtype: bool

# %%
idx_korea = (df_confirmed['Country/Region'] == 'Korea, South')
confirmed_korea_df = df_confirmed[idx_korea] # 한국만
confirmed_korea_df
# Out:
#     Province/State Country/Region        Lat        Long  1/22/20  1/23/20  \
# 160            NaN   Korea, South  35.907757  127.766922        1        1
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 160        2        2        3        4  ...   134678   135344   135929
#
#      5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# 160   136467   136983   137682   138311   138898   139431   139910
#
# [1 rows x 498 columns]

# %%
import numpy as np
confirmed_korea_np = np.array(confirmed_korea_df) # numpy 배열로 변환
confirmed_korea_np
# Out:
# array([[nan, 'Korea, South', 35.907757, 127.766922, 1, 1, 2, 2, 3, 4, 4,
#         4, 4, 11, 12, 15, 15, 16, 19, 23, 24, 24, 25, 27, 28, 28, 28, 28,
#         28, 29, 30, 31, 31, 104, 204, 433, 602, 833, 977, 1261, 1766,
#         2337, 3150, 3736, 4335, 5186, 5621, 6088, 6593, 7041, 7314, 7478,
#         7513, 7755, 7869, 7979, 8086, 8162, 8236, 8320, 8413, 8565, 8652,
#         8799, 8961, 8961, 9037, 9137, 9241, 9332, 9478, 9583, 9661, 9786,
#         9887, 9976, 10062, 10156, 10237, 10284, 10331, 10384, 10423,
#         10450, 10480, 10512, 10537, 10564, 10591, 10613, 10635, 10653,
#         10661, 10674, 10683, 10694, 10708, 10718, 10728, 10738, 10752,
#         10761, 10765, 10774, 10780, 10793, 10801, 10804, 10806, 10810,
#         10822, 10840, 10874, 10909, 10936, 10962, 10991, 11018, 11037,
#         11050, 11065, 11078, 11110, 11122, 11142, 11165, 11190, 11206,
#         11225, 11265, 11344, 11402, 11441, 11468, 11503, 11541, 11590,
# ...

# %%
confirmed_korea_np = confirmed_korea_np[:, 4:] # 4번 인덱스부터 날짜
confirmed_korea_np
# Out:
# array([[1, 1, 2, 2, 3, 4, 4, 4, 4, 11, 12, 15, 15, 16, 19, 23, 24, 24,
#         25, 27, 28, 28, 28, 28, 28, 29, 30, 31, 31, 104, 204, 433, 602,
#         833, 977, 1261, 1766, 2337, 3150, 3736, 4335, 5186, 5621, 6088,
#         6593, 7041, 7314, 7478, 7513, 7755, 7869, 7979, 8086, 8162, 8236,
#         8320, 8413, 8565, 8652, 8799, 8961, 8961, 9037, 9137, 9241, 9332,
#         9478, 9583, 9661, 9786, 9887, 9976, 10062, 10156, 10237, 10284,
#         10331, 10384, 10423, 10450, 10480, 10512, 10537, 10564, 10591,
#         10613, 10635, 10653, 10661, 10674, 10683, 10694, 10708, 10718,
#         10728, 10738, 10752, 10761, 10765, 10774, 10780, 10793, 10801,
#         10804, 10806, 10810, 10822, 10840, 10874, 10909, 10936, 10962,
#         10991, 11018, 11037, 11050, 11065, 11078, 11110, 11122, 11142,
#         11165, 11190, 11206, 11225, 11265, 11344, 11402, 11441, 11468,
#         11503, 11541, 11590, 11629, 11668, 11719, 11776, 11814, 11852,
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(confirmed_korea_np[0, :]) # 확진자 그래프
plt.show()

# %%
# 누적 사망자 수
deaths_korea_df = df_deaths[df_deaths['Country/Region'] == 'Korea, South']
deaths_korea_np = np.array(deaths_korea_df)
deaths_korea_np = deaths_korea_np[:, 4:]
deaths_korea_df
# Out:
#     Province/State Country/Region        Lat        Long  1/22/20  1/23/20  \
# 160            NaN   Korea, South  35.907757  127.766922        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 160        0        0        0        0  ...     1922     1926     1931
#
#      5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# 160     1934     1938     1940     1943     1946     1951     1957
#
# [1 rows x 498 columns]

# %%
# 누적 회복자 수
recovered_korea_df = df_recovered[df_recovered['Country/Region'] == 'Korea, South']
recovered_korea_np = np.array(recovered_korea_df)
recovered_korea_np = recovered_korea_np[:, 4:]
recovered_korea_df
# Out:
#     Province/State Country/Region        Lat        Long  1/22/20  1/23/20  \
# 145            NaN   Korea, South  35.907757  127.766922        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 145        0        0        0        0  ...   124158   125032   125881
#
#      5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# 145   126427   126993   127582   128180   128761   129739   130381
#
# [1 rows x 498 columns]

# %%
# 확진자, 사망자, 회복자 그래프 그리기
plt.figure(figsize=(10, 7))
plt.plot(confirmed_korea_np[0, :]) # 확진자
plt.plot(deaths_korea_np[0, :]) # 사망자
plt.plot(recovered_korea_np[0, :]) # 회복자

# 데이터프레임에서 인덱스 가져오기
label_x = confirmed_korea_df.columns.values[4:]

# 눈금을 표시할 위치 선택
sel_ids = range(0, len(label_x), 100)

# x축 눈금 표시
plt.xticks(sel_ids, label_x[sel_ids], fontsize=15)

# y축 눈금 표시
plt.yticks(fontsize=15)

# 범례 표시
plt.legend(['Confirmed', 'Deaths', 'Recovered'], fontsize=15)

plt.show()

# %%
# 함수 정의 - 대한민국 데이터만 추출, 날짜형식도 대한민국 스타일로 
def get_korea_data(df, value_name): # 매개변수 df -> 데이터프레임, value_name -> 확진자, 사망자, 회복자
    korea_df = df[df['Country/Region'] == 'Korea, South']
    korea_df = korea_df.drop(columns=['Province/State', 'Country/Region', 'Lat', 'Long'])
    korea_series = korea_df.sum().reset_index()
    korea_series.columns = ['날짜', value_name]
    # 날짜 형식을 datetime으로 변환
    korea_series['날짜'] = pd.to_datetime(korea_series['날짜'], format='%m/%d/%y')
    return korea_series

# %%
df_confirmed = get_korea_data(df_confirmed, '확진자')
df_deaths = get_korea_data(df_deaths, '사망자')
df_recovered = get_korea_data(df_recovered, '회복자')

# %%
df_confirmed
# Out:
#             날짜     확진자
# 0   2020-01-22       1
# 1   2020-01-23       1
# 2   2020-01-24       2
# 3   2020-01-25       2
# 4   2020-01-26       3
# ..         ...     ...
# 489 2021-05-25  137682
# 490 2021-05-26  138311
# 491 2021-05-27  138898
# 492 2021-05-28  139431
# 493 2021-05-29  139910
#
# [494 rows x 2 columns]

# %%
# 데이터 병합
df_merged = df_confirmed.merge(df_deaths, on='날짜').merge(df_recovered, on='날짜')
df_merged
# Out:
#             날짜     확진자   사망자     회복자
# 0   2020-01-22       1     0       0
# 1   2020-01-23       1     0       0
# 2   2020-01-24       2     0       0
# 3   2020-01-25       2     0       0
# 4   2020-01-26       3     0       0
# ..         ...     ...   ...     ...
# 489 2021-05-25  137682  1940  127582
# 490 2021-05-26  138311  1943  128180
# 491 2021-05-27  138898  1946  128761
# 492 2021-05-28  139431  1951  129739
# 493 2021-05-29  139910  1957  130381
#
# [494 rows x 4 columns]

# %%
# 일일 증가량 계산(오늘 - 어제)
# df_merged['확진자'] --> 누적(날짜별로 계속 증가하는 수치)
# diff() --> 차이 (오늘 - 어제)
# .fillna(0) --> 첫번째 날은 비교대상이 없으니 NaN -> 0으로 채운다
# .astype(int) --> 결과를 정수형으로
df_merged['신규 확진자'] = df_merged['확진자'].diff().fillna(0).astype(int)
df_merged['신규 사망자'] = df_merged['사망자'].diff().fillna(0).astype(int)
df_merged['신규 회복자'] = df_merged['회복자'].diff().fillna(0).astype(int)

# %%
df_merged.head(3)
# Out:
#           날짜  확진자  사망자  회복자  신규 확진자  신규 사망자  신규 회복자
# 0 2020-01-22    1    0    0       0       0       0
# 1 2020-01-23    1    0    0       0       0       0
# 2 2020-01-24    2    0    0       1       0       0

# %%
lastest = df_merged.iloc[-1]
lastest
# Out:
# 날짜        2021-05-29 00:00:00
# 확진자                    139910
# 사망자                      1957
# 회복자                    130381
# 신규 확진자                    479
# 신규 사망자                      6
# 신규 회복자                    642
# Name: 493, dtype: object

# %%
df_merged.tail(3)
# Out:
#             날짜     확진자   사망자     회복자  신규 확진자  신규 사망자  신규 회복자
# 491 2021-05-27  138898  1946  128761     587       3     581
# 492 2021-05-28  139431  1951  129739     533       5     978
# 493 2021-05-29  139910  1957  130381     479       6     642

# %%
lastest = df_merged.iloc[-1]
# 확진자 -> confirmed, 사망자 -> deaths, 회복자 -> recovered
confirmed = lastest['확진자']
deaths = lastest['사망자']
recovered = lastest['회복자']
# 조건연산자 사용 -> 결과를 담는 변수 = 참일 경우 if 조건식 else 거짓일 경우 값
# 회복률 = (회복자/확진자)*100
recovered_rate = (recovered/confirmed)*100 if confirmed else 0
# 치명률 = (사망자/확진자)*100
deaths_rate = (deaths/confirmed)*100 if confirmed else 0

# %%
recovered_rate
# Out:
# np.float64(93.18919305267673)

# %%
deaths_rate
# Out:
# np.float64(1.3987563433635908)

# %%
confirmed
# Out:
# np.int64(139910)

# %%
deaths
# Out:
# np.int64(1957)

# %%
recovered
# Out:
# np.int64(130381)
